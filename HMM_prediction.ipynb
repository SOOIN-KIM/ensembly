# %%
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime
start = datetime(2017,1,1)
end = datetime(2020,2,14)
df = pdr.DataReader('068270.KS', 'yahoo', start, end)
df = pd.DataFrame(df,columns=['Open','High','Low','Close','Volume'])
df.to_csv('stock.csv')

# %%
df.head()
df.tail()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2020-02-10  171000.0  175500.0  169500.0  173000.0   496142.0
# 2020-02-11  174000.0  176500.0  172500.0  173500.0   433405.0
# 2020-02-12  174000.0  175000.0  172000.0  174000.0   326275.0
# 2020-02-13  175500.0  181000.0  175500.0  178500.0  1215090.0
# 2020-02-14  178000.0  182000.0  177500.0  181000.0   645545.0

# %%
price = pd.read_csv('stock.csv')
price = price.set_index('Date')
price.tail()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2020-02-10  171000.0  175500.0  169500.0  173000.0   496142.0
# 2020-02-11  174000.0  176500.0  172500.0  173500.0   433405.0
# 2020-02-12  174000.0  175000.0  172000.0  174000.0   326275.0
# 2020-02-13  175500.0  181000.0  175500.0  178500.0  1215090.0
# 2020-02-14  178000.0  182000.0  177500.0  181000.0   645545.0

# %%
price.index = pd.DatetimeIndex(price.index)
price.info
# Out:
# <bound method DataFrame.info of                      Open           High  ...          Close     Volume
# Date                                      ...
# 2017-01-02   98496.898438   99137.703125  ...   99046.203125   473644.0
# 2017-01-03   98588.500000   99046.203125  ...   97581.500000   417380.0
# 2017-01-04   97947.703125   97947.703125  ...   97123.796875   382323.0
# 2017-01-05   97398.398438   98405.398438  ...   97398.398438   340866.0
# 2017-01-06   96940.703125   97306.898438  ...   96391.500000   303191.0
# ...                   ...            ...  ...            ...        ...
# 2020-02-10  171000.000000  175500.000000  ...  173000.000000   496142.0
# 2020-02-11  174000.000000  176500.000000  ...  173500.000000   433405.0
# 2020-02-12  174000.000000  175000.000000  ...  174000.000000   326275.0
# 2020-02-13  175500.000000  181000.000000  ...  178500.000000  1215090.0
# 2020-02-14  178000.000000  182000.000000  ...  181000.000000   645545.0
#
# [756 rows x 5 columns]>

# %%
import numpy as np
price_array = np.asarray(price.Close)
price_array.shape
# Out:
# (756,)

# %%
price_array = price_array.reshape(1, -1)
price_array.shape
# Out:
# (1, 756)

# %%
price_array.max()
# Out:
# 348740.0

# %%
from hmmlearn import hmm

# %%
import warnings
warnings.filterwarnings("ignore")

num_components = 100
hmm            = GaussianHMM(n_components    = num_components,
                             covariance_type = 'diag',   
                             n_iter          = 1000)
hmm.fit(price_array.T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-3164a45f60d8> in <module>()
#       3
#       4 num_components = 100
# ----> 5 hmm            = GaussianHMM(n_components    = num_components,
#       6                              covariance_type = 'diag',
#       7                              n_iter          = 1000)
#
# NameError: name 'GaussianHMM' is not defined
